# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#LCOH

data = [[71.5, 75.4, 68.4, 72.1],
        [69.1, 74.3, 66.1, 71.1]]

X = np.arange(4)
fig = plt.figure(figsize=(8, 5))
ax = fig.add_axes([0,0,1,1])

# define the width of each bar and the spacing between them
bar_width = 0.15
bar_spacing = 0.15

ax.bar(X, data[0], color='b', width=bar_width, label='Scenario 1')
ax.bar(X + bar_width + bar_spacing, data[1], color='r', width=bar_width, label='Scenario 3')

# set the x-axis tick marks in the middle of each group of bars
ax.set_xticks(X+(bar_width + bar_spacing)/2)
ax.set_xticklabels(['Case 1a \n 70% (H2) / 30% (E) \n WC6 - 100 km', 'Case 1b \n 30% (H2) / 70% (E) \n WC6 - 100 km', 'Case 2a \n 70% (H2) / 30% (E) \n WC12 - 180 km', 'Case 2b \n 30% (H2) / 70% (E) \n WC12 - 180 km'])

# set y-axis limits
ax.set_ylim(0, 100)
ax.set_ylabel('Efficiency (%)', fontsize = 12)

# add legend
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# define the font size for the values
value_fontsize = 10

# loop over the data and add the values above each bar
for i in range(len(X)):
    for j in range(len(data)):
        ax.text(X[i] + j * (bar_width + bar_spacing), data[j][i]+1, f'{data[j][i]:.2f} %', ha='center', fontsize=value_fontsize)

# set the title
ax.set_title('Comparison of Supply Chain Efficiency\n Varying Electricity-to-H2 Ratios, Wind Park Capacity and Distances to Shore', fontsize=14)
ax.yaxis.grid(True, linestyle='--', which='major', color='grey', alpha=.25)

plt.show()

# %%
#LCOH

data = [[8.34, 8.34, 8.71, 8.71],
        [8.80, 8.80, 9.19, 9.19],
        [8.96, 8.92, 9.28, 9.22],
        [9.75, 9.70, 10.08, 10.00]]

X = np.arange(4)
fig = plt.figure(figsize=(8, 5))
ax = fig.add_axes([0,0,1,1])

# define the width of each bar and the spacing between them
bar_width = 0.15
bar_spacing = 0.05

ax.bar(X, data[0], color='b', width=bar_width, label='Scenario 1')
ax.bar(X + bar_width + bar_spacing, data[1], color='g', width=bar_width, label='Scenario 2')
ax.bar(X + 2 * (bar_width + bar_spacing), data[2], color='r', width=bar_width, label='Scenario 3')
ax.bar(X + 3 * (bar_width + bar_spacing), data[3], color='orange', width=bar_width, label='Scenario 4')

# set the x-axis limits
ax.set_xlim(-bar_width, len(X) - 1 + 4 * (bar_width + bar_spacing))

# set the x-axis tick marks in the middle of each group of bars
ax.set_xticks(X + 1.5 * (bar_width + bar_spacing))
ax.set_xticklabels(['Case 1a \n 70% (H2) / 30% (E) \n WC6 - 100 km', 'Case 1b \n 30% (H2) / 70% (E) \n WC6 - 100 km', 'Case 2a \n 70% (H2) / 30% (E) \n WC12 - 180 km', 'Case 2b \n 30% (H2) / 70% (E) \n WC12 - 180 km'])

# set y-axis limits
ax.set_ylim(0, 14)
ax.set_ylabel('LCOH (EUR / kg)', fontsize = 12)

# add legend
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# define the font size for the values
value_fontsize = 8

# loop over the data and add the values above each bar
for i in range(len(X)):
    for j in range(len(data)):
        ax.text(X[i] + j * (bar_width + bar_spacing), data[j][i]+0.2, f'{data[j][i]:.2f}', ha='center', fontsize=value_fontsize)

# set the title
ax.set_title('Comparison of LCOH for Different Scenarios\n Varying Electricity-to-H2 Ratios, Wind Park Capacity and Distances to Shore', fontsize=14)
ax.yaxis.grid(True, linestyle='--', which='major', color='grey', alpha=.25)

plt.show()

# %%
#LCOE

data = [[0.150, 0.150, 0.156, 0.156],
        [0.158, 0.158, 0.165, 0.165],
        [0.157, 0.156, 0.163, 0.161],
        [0.196, 0.195, 0.203, 0.202]]

X = np.arange(4)
fig = plt.figure(figsize=(8, 5))
ax = fig.add_axes([0,0,1,1])

# define the width of each bar and the spacing between them
bar_width = 0.15
bar_spacing = 0.05

ax.bar(X, data[0], color='b', width=bar_width, label='Scenario 1')
ax.bar(X + bar_width + bar_spacing, data[1], color='g', width=bar_width, label='Scenario 2')
ax.bar(X + 2 * (bar_width + bar_spacing), data[2], color='r', width=bar_width, label='Scenario 3')
ax.bar(X + 3 * (bar_width + bar_spacing), data[3], color='orange', width=bar_width, label='Scenario 4')

# set the x-axis limits
ax.set_xlim(-bar_width, len(X) - 1 + 4 * (bar_width + bar_spacing))

# set the x-axis tick marks in the middle of each group of bars
ax.set_xticks(X + 1.5 * (bar_width + bar_spacing))
ax.set_xticklabels(['Case 1a \n 70% (H2) / 30% (E) \n WC6 - 100 km', 'Case 1b \n 30% (H2) / 70% (E) \n WC6 - 100 km', 'Case 2a \n 70% (H2) / 30% (E) \n WC12 - 180 km', 'Case 2b \n 30% (H2) / 70% (E) \n WC12 - 180 km'])

# set y-axis limits
ax.set_ylim(0, 0.4)

ax.set_ylabel('LCOE (EUR / kWh)', fontsize = 12)

# add legend
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# define the font size for the values
value_fontsize = 8

# loop over the data and add the values above each bar
for i in range(len(X)):
    for j in range(len(data)):
        ax.text(X[i] + j * (bar_width + bar_spacing), data[j][i]+0.02, f'{data[j][i]:.3f}', ha='center', fontsize=value_fontsize)

# set the title
ax.set_title('Comparison of LCOE for Different Scenarios\n Varying Electricity-to-H2 Ratios, Wind Park Capacity and Distances to Shore', fontsize=14)
ax.yaxis.grid(True, linestyle='--', which='major', color='grey', alpha=.25)

plt.show()

# %%
data = [[27.9, 25.6, 55.7, 51.1],
        [2.1, 8.2, 1.7, 13.4],
        [23.4, 21.5, 46.8, 43.0],
        [1.2, 6.2, 0.29, 10.1],
        [28.7, 26.5, 56.8, 52.3],
        [0.4, 7.0, -1.1, 11.7],
        [25.3, 23.6, 50.0, 46.5],
        [-1.4, 3.8, -4.3, 6.0]]

X = np.arange(4)
fig = plt.figure(figsize=(10, 6))
ax = fig.add_axes([0,0,1,1])

# define the width of each bar and the spacing between them
bar_width = 0.1
bar_spacing = 0.01

ax.bar(X, data[0], color='b', width=bar_width, label='Scenario 1 - Total discounted costs')
ax.bar(X + bar_width + bar_spacing, data[1], color='white', edgecolor='b', width=bar_width, hatch='\\', label='Scenario 1 - Final year cum. NPV (with revenues)')
ax.bar(X + 2 * (bar_width + bar_spacing), data[2], color='r', width=bar_width, label='Scenario 2 - Total discounted costs')
ax.bar(X + 3 * (bar_width + bar_spacing), data[3], color='white', edgecolor='r', width=bar_width, hatch='\\', label='Scenario 2 - Final year cum. NPV (with revenues)')
ax.bar(X + 4 * (bar_width + bar_spacing), data[4], color='g', width=bar_width, label='Scenario 3 - Total discounted costs')
ax.bar(X + 5 * (bar_width + bar_spacing), data[5], color='white', edgecolor='g', width=bar_width, hatch='\\', label='Scenario 3 - Final year cum. NPV (with revenues)')
ax.bar(X + 6 * (bar_width + bar_spacing), data[6], color='orange', width=bar_width, label='Scenario 4 - Total discounted costs')
ax.bar(X + 7 * (bar_width + bar_spacing), data[7], color='white', edgecolor='orange', width=bar_width, hatch='\\', label='Scenario 4 - Final year cum. NPV (with revenues)')

# set the x-axis limits
ax.set_xlim(-bar_width, len(X) - 1 + 8 * (bar_width + bar_spacing))

# set the x-axis tick marks in the middle of each group of bars
ax.set_xticks(X + 3.5 * (bar_width + bar_spacing))
ax.set_xticklabels(['Case 1a \n 70% (H2) / 30% (E) \n WC6 - 100 km', 'Case 1b \n 30% (H2) / 70% (E) \n WC6 - 100 km', 'Case 2a \n 70% (H2) / 30% (E) \n WC12 - 180 km', 'Case 2b \n 30% (H2) / 70% (E) \n WC12 - 180 km'])

ax.set_ylabel('Euros ($\\mathregular{10^9}$)', fontsize=14)

# set y-axis limits
ax.set_ylim(-6, 60)

# add horizontal line at y=0
ax.axhline(0, color='black')

# add legend
ax.legend(bbox_to_anchor=(1.01, 1), loc='upper left', fontsize = 8)

# define the font size for the values
value_fontsize = 8

# loop over the data and add the values above each bar
for i in range(len(X)):
    for j in range(len(data)):
        if data[j][i] < 0:
            ax.text(X[i] + j * (bar_width + bar_spacing), data[j][i]-1.5, f'{data[j][i]:.2f}', ha='center', fontsize=value_fontsize)
        else:
            ax.text(X[i] + j * (bar_width + bar_spacing), data[j][i]+0.5, f'{data[j][i]:.2f}', ha='center', fontsize=value_fontsize)

# set the title
ax.set_title('Comparison of Total Costs and Cumulative NPV for Four Scenarios \n Varying Electricity-to-H2 Ratios, Wind Park Capacity and Distances to Shore', fontsize=15)
ax.yaxis.grid(True, linestyle='--', which='major', color='grey', alpha=.25)

plt.show()

# %%
data = [[12.8, 2.10, 0.40, 8.20, 7.00],
        [22.4, 1.70, -1.10, 13.40, 11.70]]

X = np.arange(5)
fig = plt.figure(figsize=(10, 6))
ax = fig.add_axes([0,0,1,1])

# define the width of each bar and the spacing between them
bar_width = 0.3
bar_spacing = 0.10

ax.bar(X, data[0], width=bar_width, edgecolor = 'black', label='Case 1 (6 GW, 100 km offshore)')
ax.bar(X + bar_width + bar_spacing, data[1], width=bar_width, edgecolor = 'black', label='Case 2 (12 GW, 180 km offshore)')

# set the x-axis limits
ax.set_xlim(-bar_width, len(X) - 1 + 2 * (bar_width + bar_spacing))

# set the x-axis tick marks in the middle of each group of bars
ax.set_xticks(X + 0.5 * (bar_width) + bar_spacing)
ax.set_xticklabels(['Reference - Scenario 1 \n 100% (E) ', 
                    'Scenario 1 \n Onshore electrolysis \n 70% (H2) / 30% (E)', 
                    'Scenario 3 \n Offshore electrolysis \n 70% (H2) / 30% (E)', 
                    'Scenario 1 \n Onshore electrolysis \n 30% (H2) / 70% (E)', 
                    'Scenario 3 \n Offshore electrolysis \n 30% (H2) / 70% (E)'], fontsize=11)

# set y-axis limits
ax.set_ylim(-5, 25)
ax.set_ylabel('Euros ($\\mathregular{10^9}$)', fontsize=14)

# add horizontal line at y=0
ax.axhline(0, color='black')

# add legend
ax.legend(bbox_to_anchor=(1.01, 1), loc='upper left', fontsize=11)

# define the font size for the values
value_fontsize = 11

# loop over the data and add the values above each bar
for i in range(len(X)):
    for j in range(len(data)):
        if data[j][i] < 0:
            ax.text(X[i] + j * (bar_width + bar_spacing), data[j][i]-1.5, f'{data[j][i]:.2f}', ha='center', fontsize=value_fontsize)
        else:
            ax.text(X[i] + j * (bar_width + bar_spacing), data[j][i]+0.5, f'{data[j][i]:.2f}', ha='center', fontsize=value_fontsize)

# set the title
ax.set_title('Cumulative NPV Comparison of Different Cases \n Varying Electricity-to-H2 Ratios and Electrolysis Location', fontsize=17)

# Add a grid
ax.yaxis.grid(True, linestyle='--', which='major', color='grey', alpha=.25)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the data for each case
cases = ['All components (10%)', 'Foundation & Cables (30%)', 'Foundation & Cables (5%)',
         'Turbines (30%)', 'Turbines (5%)', 'Electrolysis system (30%)',
         'Electrolysis system (5%)', 'Artificial island (30%)', 'Artificial island (5%)']
lcoh_means = [9.20, 9.23, 9.22, 9.23, 9.23, 9.22, 9.22, 9.22, 9.23]
lcoh_stdevs = [0.39, 0.72, 0.36, 0.87, 0.33, 0.59, 0.37, 0.42, 0.41]

# Create the plot
fig, ax = plt.subplots(figsize=(15,6), facecolor='white')
ax.errorbar(cases, lcoh_means, yerr=lcoh_stdevs, fmt='o', markersize=10, color='red', capsize=5, ecolor='black', label='LCOH mean with standard deviation')

# Add axis labels and title
plt.xlabel('Component (standard deviation)', fontsize=14)
plt.ylabel('LCOH (€ / kg)', fontsize=14)
plt.title('Analysing the sensitivity of LCOH to component price uncertainty', fontsize = 18)

# Add a horizontal line for LCOH mean
plt.axhline(y=9.20, color='black', linestyle='--', label='Base-case LCOH mean')

plt.xticks(rotation=30)

# Add a legend
legend = plt.legend(fontsize=12)
plt.setp(legend.get_title(), color='black')
plt.setp(legend.get_lines(), linewidth=1.5)

# Add a grid
ax.yaxis.grid(True, linestyle='--', which='major', color='grey', alpha=.25)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the data for each case
cases = ['Foundation & Cables (30%)', 'Foundation & Cables (5%)',
         'Turbines (30%)', 'Turbines (5%)', 'Electrolysis system (30%)',
         'Electrolysis system (5%)', 'Artificial island (30%)', 'Artificial island (5%)']
lcoh_stdevs = [0.72, 0.36, 0.87, 0.33, 0.59, 0.37, 0.42, 0.41]
lcoh_base = 0.39  # Base case is the first case
lcoh_pcts = [(x-lcoh_base)/lcoh_base * 100 for x in lcoh_stdevs]  # Percentage change from base case

# Define the colors for the bars
colors = ['#1f77b4']*2 + ['#ff7f0e']*2 + ['#2ca02c']*2 + ['#d62728']*2

# Create the bar chart
fig, ax = plt.subplots(figsize=(15,6))
bars = ax.bar(cases, lcoh_pcts, color=colors, capsize=10)

# set y-axis limits
ax.set_ylim(-30, 140)

# Add a horizontal line at 0%
plt.axhline(y=0, color='gray', linestyle='--', linewidth=1)

# Add axis labels and title
plt.xlabel('Component (standard deviation)', fontsize=14)
plt.ylabel('Change in standard deviation (%)', fontsize=14)
plt.title('Change in standard deviation of LCOH due to varying component price uncertainty', fontsize = 18)

plt.xticks(rotation=30)

# Add percentages on top of the bars, below for negative values
for bar in bars:
    height = bar.get_height()
    if height >= 0:
        ax.annotate(f'{height:.0f}%', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points", ha='center', va='bottom', fontsize=12)
    else:
        ax.annotate(f'{height:.0f}%', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, -3),  # 3 points vertical offset
                    textcoords="offset points", ha='center', va='top', fontsize=12)
# Add a grid
ax.yaxis.grid(True, linestyle='--', which='major', color='grey', alpha=.25)
        
# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the data
components = ['Foundation & Cables', 'Turbine', 'AC Substation', 'HVDC Converter \n& cables', 'Artificial Island', 'Electrolysis system', 'H2 Pipeline']
prices_2a = [9615262324.172846, 12444233983, 2073239971, 4718048470, 1416904591, 11410418161, 187224145.6]
prices_2b = [4120826710, 5333243135, 888531416, 2022020772, 486485910, 4890179211, 80238919]
percent_diff = [-57.14, -57.14, -57.14, -57.14, -65.67, -57.14, -57.14]

# Create the figure and axes
fig, ax = plt.subplots(figsize=(13,6))

# Create the bar chart
bar_width = 0.3
bar_space = 0.1  # Decreased from 0.2
ax.bar(np.arange(len(components)), prices_2a, width=bar_width,color='green', label='Case 2a (70% H2)')
ax.bar(np.arange(len(components))+bar_width+bar_space, prices_2b, width=bar_width,color='purple', label='Case 2b (30% H2)')

# Add the percentage difference as annotations for both sets of bars
for i, comp in enumerate(components):
    if percent_diff[i] == -65.67:
        ax.annotate(f'{percent_diff[i]:.2f}%', xy=(i+bar_width+bar_space, prices_2b[i]), xytext=(i+bar_width*1.1+bar_space, prices_2b[i]+250000000), ha='center', color='red', fontsize=12, bbox=dict(boxstyle='round,pad=0.4', edgecolor='red', facecolor='none', linewidth=2)
)
    else:
        ax.annotate(f'{percent_diff[i]:.2f}%', xy=(i+bar_width+bar_space, prices_2b[i]), xytext=(i+bar_width*1.1+bar_space, prices_2b[i]+250000000), ha='center', color='red', fontsize=12)
    

# Add labels and title
ax.set_ylabel('Cumulative NPV Over Total Project (EUR)', fontsize = 14)
ax.set_xlabel('Components', fontsize = 14)
ax.set_title('Comparison of Costs Allocated to Hydrogen: 70% H2 vs 30% H2', fontsize = 18)
ax.set_xticks(np.arange(len(components))+(bar_width+bar_space)/2)
ax.set_xticklabels(components)
ax.legend()

# Show the plot
plt.show()
